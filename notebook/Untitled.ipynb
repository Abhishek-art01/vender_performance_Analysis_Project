# %%
'''hello i am writhing comment of multiple line
so this is very importent for writing muliple line
i can write now a multiple code'''

# %%
tupul =  ('Apple', 8, 'Blue')
tupul.count(8)
len(tupul)
# Out:
# 3

# %%
tupul.index(8)
# Out:
# 1

# %%
    def  count_to(n):
        count = 1
        while count <=n:
            yield count
            count+=1
        

    number = int(input("enter any number:"))

    for n in count_to(number):
        print(n)
# Out:
# enter any number:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 8
#       4         yield count
#       5         count+=1
# ----> 8 number = int(input("enter any number:"))
#      10 for n in count_to(number):
#      11     print(n)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
def bye() -> None:
    return "Good bye"
            
print(bye())
# Out:
# Good bye

# %%
import math
from math import factorial as fact
fact(99)<50**99
# Out:
# True
